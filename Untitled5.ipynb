# %%
import pandas as pd
df = pd.read_excel('Pivot.xlsx')
df.head()
# Out:
#         Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 0 2020-01-01      Quad    Wschód         Szymon     AA      16    432.17
# 1 2020-01-02    Bellen  Południe       Grzegorz   KBTB      24    528.50
# 2 2020-01-02      Quad    Zachód        Paulina    AST      30    810.71
# 3 2020-01-02    Bellen    Zachód        Paulina   SFWK      19    418.54
# 4 2020-01-03  Sunshine    Wschód        Paulina     FM      38    722.22
#
#    Koszty
# 0  232.99
# 1  240.35
# 2  435.64
# 3  190.05
# 4  304.06

# %%
import numpy as np
df.pivot_table(values='Sprzedaż',index='Przedstawiciel',columns='Region',aggfunc=np.sum)
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_30696\766879611.py:2: FutureWarning: The provided callable <function sum at 0x000001F85BBE8D60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(values='Sprzedaż',index='Przedstawiciel',columns='Region',aggfunc=np.sum)
# Region          Południe   Wschód   Zachód  ZachódCentrum
# Przedstawiciel
# Franciszek       3029.98  8919.85  1608.96            NaN
# Grzegorz         2040.69  4854.15  4376.02         154.34
# Krystian         2228.68  7894.56  2006.31            NaN
# Patryk           5769.22  5670.96  2828.02         816.84
# Paulina          1954.58  6696.10  9790.96        1449.21
# Szymon           4791.80  3633.19  4168.15            NaN

# %%
df.pivot_table(values='Sprzedaż',index='Przedstawiciel',columns='Region',aggfunc=np.sum).fillna(0).round(2)
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_30696\3780089852.py:1: FutureWarning: The provided callable <function sum at 0x000001F85BBE8D60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(values='Sprzedaż',index='Przedstawiciel',columns='Region',aggfunc=np.sum).fillna(0).round(2)
# Region          Południe   Wschód   Zachód  ZachódCentrum
# Przedstawiciel
# Franciszek       3029.98  8919.85  1608.96           0.00
# Grzegorz         2040.69  4854.15  4376.02         154.34
# Krystian         2228.68  7894.56  2006.31           0.00
# Patryk           5769.22  5670.96  2828.02         816.84
# Paulina          1954.58  6696.10  9790.96        1449.21
# Szymon           4791.80  3633.19  4168.15           0.00

# %%
df.pivot_table(values='Sprzedaż',index=['Region','Przedstawiciel'],aggfunc=np.sum).round(2)
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_30696\1242883362.py:1: FutureWarning: The provided callable <function sum at 0x000001F85BBE8D60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(values='Sprzedaż',index=['Region','Przedstawiciel'],aggfunc=np.sum).round(2)
#                               Sprzedaż
# Region        Przedstawiciel
# Południe      Franciszek       3029.98
#               Grzegorz         2040.69
#               Krystian         2228.68
#               Patryk           5769.22
#               Paulina          1954.58
#               Szymon           4791.80
# Wschód        Franciszek       8919.85
#               Grzegorz         4854.15
#               Krystian         7894.56
#               Patryk           5670.96
#               Paulina          6696.10
#               Szymon           3633.19
# Zachód        Franciszek       1608.96
#               Grzegorz         4376.02
#               Krystian         2006.31
#               Patryk           2828.02
#               Paulina          9790.96
#               Szymon           4168.15
# ZachódCentrum Grzegorz          154.34
#               Patryk            816.84
#               Paulina          1449.21

# %%
df.pivot_table(values='Sprzedaż',index='Region',aggfunc=[len,np.max,np.min]).round(0)
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_30696\2356561599.py:1: FutureWarning: The provided callable <function max at 0x000001F85BBE9440> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.pivot_table(values='Sprzedaż',index='Region',aggfunc=[len,np.max,np.min]).round(0)
# C:\Users\Start\AppData\Local\Temp\ipykernel_30696\2356561599.py:1: FutureWarning: The provided callable <function min at 0x000001F85BBE9580> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.pivot_table(values='Sprzedaż',index='Region',aggfunc=[len,np.max,np.min]).round(0)
#                    len      max      min
#               Sprzedaż Sprzedaż Sprzedaż
# Region
# Południe            27   1512.0    115.0
# Wschód              50   1675.0    153.0
# Zachód              24   5001.0    132.0
# ZachódCentrum        4   1449.0    154.0

# %%
import pandas as pd
df = pd.read_excel('Pivot.xlsx')
df.head()
# Out:
#         Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 0 2020-01-01      Quad    Wschód         Szymon     AA      16    432.17
# 1 2020-01-02    Bellen  Południe       Grzegorz   KBTB      24    528.50
# 2 2020-01-02      Quad    Zachód        Paulina    AST      30    810.71
# 3 2020-01-02    Bellen    Zachód        Paulina   SFWK      19    418.54
# 4 2020-01-03  Sunshine    Wschód        Paulina     FM      38    722.22
#
#    Koszty
# 0  232.99
# 1  240.35
# 2  435.64
# 3  190.05
# 4  304.06

# %%
def commission_fee(x):


    if x <= 300:
        return 0
    elif x <= 900:
        return x * 0.03
    else:
        return x * 0.06

# %%
df['commission_fee'] = df['Sprzedaż'].apply(lambda x: commission_fee(x))

# %%
df
# Out:
#           Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 0   2020-01-01      Quad    Wschód         Szymon     AA      16    432.17
# 1   2020-01-02    Bellen  Południe       Grzegorz   KBTB      24    528.50
# 2   2020-01-02      Quad    Zachód        Paulina    AST      30    810.71
# 3   2020-01-02    Bellen    Zachód        Paulina   SFWK      19    418.54
# 4   2020-01-03  Sunshine    Wschód        Paulina     FM      38    722.22
# ..         ...       ...       ...            ...    ...     ...       ...
# 100 2020-01-29    Bellen    Wschód       Krystian    AST      50   1100.14
# 101 2020-01-29      Quad    Wschód       Grzegorz   PLOT      10    270.50
# 102 2020-01-30  Sunshine  Południe         Szymon    TTT      23    437.81
# 103 2020-01-30      Quad  Południe         Szymon    TTT      25    675.75
# 104 2020-01-30  Sunshine    Zachód       Grzegorz    DFR      49    931.49
#
#      Koszty  commission_fee
# 0    232.99         12.9651
# 1    240.35         15.8550
# 2    435.64         24.3213
# 3    190.05         12.5562
# 4    304.06         21.6666
# ..      ...             ...
# 100  500.16         66.0084
# 101  145.57          0.0000
# 102  184.16         13.1343
# 103  362.89         20.2725
# 104  392.84         55.8894
#
# [105 rows x 9 columns]

# %%
df['Produkt_len'] = df['Produkt'].apply(len)

# %%
df
# Out:
#           Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 0   2020-01-01      Quad    Wschód         Szymon     AA      16    432.17
# 1   2020-01-02    Bellen  Południe       Grzegorz   KBTB      24    528.50
# 2   2020-01-02      Quad    Zachód        Paulina    AST      30    810.71
# 3   2020-01-02    Bellen    Zachód        Paulina   SFWK      19    418.54
# 4   2020-01-03  Sunshine    Wschód        Paulina     FM      38    722.22
# ..         ...       ...       ...            ...    ...     ...       ...
# 100 2020-01-29    Bellen    Wschód       Krystian    AST      50   1100.14
# 101 2020-01-29      Quad    Wschód       Grzegorz   PLOT      10    270.50
# 102 2020-01-30  Sunshine  Południe         Szymon    TTT      23    437.81
# 103 2020-01-30      Quad  Południe         Szymon    TTT      25    675.75
# 104 2020-01-30  Sunshine    Zachód       Grzegorz    DFR      49    931.49
#
#      Koszty  commission_fee  Produkt_len
# 0    232.99         12.9651            4
# 1    240.35         15.8550            6
# 2    435.64         24.3213            4
# 3    190.05         12.5562            6
# 4    304.06         21.6666            8
# ..      ...             ...          ...
# 100  500.16         66.0084            6
# 101  145.57          0.0000            4
# 102  184.16         13.1343            8
# 103  362.89         20.2725            4
# 104  392.84         55.8894            8
#
# [105 rows x 10 columns]

# %%
import math
df['#_opakowań'] = df['Sztuki'].apply(lambda x: math.ceil(x/5))

# %%
df
# Out:
#           Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 0   2020-01-01      Quad    Wschód         Szymon     AA      16    432.17
# 1   2020-01-02    Bellen  Południe       Grzegorz   KBTB      24    528.50
# 2   2020-01-02      Quad    Zachód        Paulina    AST      30    810.71
# 3   2020-01-02    Bellen    Zachód        Paulina   SFWK      19    418.54
# 4   2020-01-03  Sunshine    Wschód        Paulina     FM      38    722.22
# ..         ...       ...       ...            ...    ...     ...       ...
# 100 2020-01-29    Bellen    Wschód       Krystian    AST      50   1100.14
# 101 2020-01-29      Quad    Wschód       Grzegorz   PLOT      10    270.50
# 102 2020-01-30  Sunshine  Południe         Szymon    TTT      23    437.81
# 103 2020-01-30      Quad  Południe         Szymon    TTT      25    675.75
# 104 2020-01-30  Sunshine    Zachód       Grzegorz    DFR      49    931.49
#
#      Koszty  commission_fee  Produkt_len  #_opakowań
# 0    232.99         12.9651            4           4
# 1    240.35         15.8550            6           5
# 2    435.64         24.3213            4           6
# 3    190.05         12.5562            6           4
# 4    304.06         21.6666            8           8
# ..      ...             ...          ...         ...
# 100  500.16         66.0084            6          10
# 101  145.57          0.0000            4           2
# 102  184.16         13.1343            8           5
# 103  362.89         20.2725            4           5
# 104  392.84         55.8894            8          10
#
# [105 rows x 11 columns]

# %%
def bonus(row):

    margin = (row['Sprzedaż'] - row['Koszty'])/row['Sprzedaż']

    if margin > 0.55:
        return 200
    else:
        return 0

# %%
df['Bonus'] = df.apply(lambda row: bonus(row),axis=1)
df.sample(10)
# Out:
#           Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 50  2020-01-17      Quad    Wschód       Grzegorz   SFWK      43   1161.25
# 72  2020-01-21    Bellen  Południe         Patryk    TRU      11    242.26
# 48  2020-01-16   Carlota  Południe         Patryk     QT      31    713.28
# 38  2020-01-12    Sunset    Wschód       Grzegorz    ITW      19    399.02
# 90  2020-01-27   Carlota    Zachód       Grzegorz     QT      10    230.25
# 9   2020-01-05    Sunset  Południe        Paulina    TTT      57   1197.90
# 103 2020-01-30      Quad  Południe         Szymon    TTT      25    675.75
# 87  2020-01-26    Bellen    Wschód       Grzegorz    PSA      21    462.17
# 42  2020-01-13    Bellen    Wschód        Paulina    PSA      40    880.60
# 12  2020-01-06  Sunshine    Wschód     Franciszek    PSA      54   1026.96
#
#      Koszty  commission_fee  Produkt_len  #_opakowań  Bonus
# 50   623.75         69.6750            4           9      0
# 72   110.91          0.0000            6           3      0
# 48   341.34         21.3984            7           7      0
# 38   176.55         11.9706            6           4    200
# 90   110.43          0.0000            7           2      0
# 9    527.98         71.8740            6          12    200
# 103  362.89         20.2725            4           5      0
# 87   210.81         13.8651            6           5      0
# 42   400.47         26.4180            6           8      0
# 12   432.75         61.6176            8          11    200

# %%
car_dict = dict(zip(df['Przedstawiciel'].unique(),['Mazda','Toyota','BMW','Audi','Fiat','Seat']))
car_dict
# Out:
# {'Szymon': 'Mazda',
#  'Grzegorz': 'Toyota',
#  'Paulina': 'BMW',
#  'Krystian': 'Audi',
#  'Franciszek': 'Fiat',
#  'Patryk': 'Seat'}

# %%
df['Marka_samochodu'] = df['Przedstawiciel'].map(car_dict)

# %%
df
# Out:
#           Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 0   2020-01-01      Quad    Wschód         Szymon     AA      16    432.17
# 1   2020-01-02    Bellen  Południe       Grzegorz   KBTB      24    528.50
# 2   2020-01-02      Quad    Zachód        Paulina    AST      30    810.71
# 3   2020-01-02    Bellen    Zachód        Paulina   SFWK      19    418.54
# 4   2020-01-03  Sunshine    Wschód        Paulina     FM      38    722.22
# ..         ...       ...       ...            ...    ...     ...       ...
# 100 2020-01-29    Bellen    Wschód       Krystian    AST      50   1100.14
# 101 2020-01-29      Quad    Wschód       Grzegorz   PLOT      10    270.50
# 102 2020-01-30  Sunshine  Południe         Szymon    TTT      23    437.81
# 103 2020-01-30      Quad  Południe         Szymon    TTT      25    675.75
# 104 2020-01-30  Sunshine    Zachód       Grzegorz    DFR      49    931.49
#
#      Koszty  commission_fee  Produkt_len  #_opakowań  Bonus Marka_samochodu
# 0    232.99         12.9651            4           4      0           Mazda
# 1    240.35         15.8550            6           5      0          Toyota
# 2    435.64         24.3213            4           6      0             BMW
# 3    190.05         12.5562            6           4      0             BMW
# 4    304.06         21.6666            8           8    200             BMW
# ..      ...             ...          ...         ...    ...             ...
# 100  500.16         66.0084            6          10      0            Audi
# 101  145.57          0.0000            4           2      0          Toyota
# 102  184.16         13.1343            8           5    200           Mazda
# 103  362.89         20.2725            4           5      0           Mazda
# 104  392.84         55.8894            8          10    200          Toyota
#
# [105 rows x 13 columns]

# %%
df.applymap(lambda x: x.upper() if isinstance(x,str) else x)
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_30696\3483673579.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x.upper() if isinstance(x,str) else x)
#           Data   Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 0   2020-01-01      QUAD    WSCHÓD         SZYMON     AA      16    432.17
# 1   2020-01-02    BELLEN  POŁUDNIE       GRZEGORZ   KBTB      24    528.50
# 2   2020-01-02      QUAD    ZACHÓD        PAULINA    AST      30    810.71
# 3   2020-01-02    BELLEN    ZACHÓD        PAULINA   SFWK      19    418.54
# 4   2020-01-03  SUNSHINE    WSCHÓD        PAULINA     FM      38    722.22
# ..         ...       ...       ...            ...    ...     ...       ...
# 100 2020-01-29    BELLEN    WSCHÓD       KRYSTIAN    AST      50   1100.14
# 101 2020-01-29      QUAD    WSCHÓD       GRZEGORZ   PLOT      10    270.50
# 102 2020-01-30  SUNSHINE  POŁUDNIE         SZYMON    TTT      23    437.81
# 103 2020-01-30      QUAD  POŁUDNIE         SZYMON    TTT      25    675.75
# 104 2020-01-30  SUNSHINE    ZACHÓD       GRZEGORZ    DFR      49    931.49
#
#      Koszty  commission_fee  Produkt_len  #_opakowań  Bonus Marka_samochodu
# 0    232.99         12.9651            4           4      0           MAZDA
# 1    240.35         15.8550            6           5      0          TOYOTA
# 2    435.64         24.3213            4           6      0             BMW
# 3    190.05         12.5562            6           4      0             BMW
# 4    304.06         21.6666            8           8    200             BMW
# ..      ...             ...          ...         ...    ...             ...
# 100  500.16         66.0084            6          10      0            AUDI
# 101  145.57          0.0000            4           2      0          TOYOTA
# 102  184.16         13.1343            8           5    200           MAZDA
# 103  362.89         20.2725            4           5      0           MAZDA
# 104  392.84         55.8894            8          10    200          TOYOTA
#
# [105 rows x 13 columns]

# %%
df['Data'] = pd.to_datetime(df['Data'])
df['Data'].dt.day_name().head()
# Out:
# 0    Wednesday
# 1     Thursday
# 2     Thursday
# 3     Thursday
# 4       Friday
# Name: Data, dtype: object

# %%
df['Data'].dt.month_name().head()
# Out:
# 0    January
# 1    January
# 2    January
# 3    January
# 4    January
# Name: Data, dtype: object

# %%
df['Data'].dt.is_month_start.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Data, dtype: bool

# %%
df[df['Data'].dt.day_name()=='Thursday'].head()
# Out:
#          Data  Produkt    Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 1  2020-01-02   Bellen  Południe       Grzegorz   KBTB      24    528.50
# 2  2020-01-02     Quad    Zachód        Paulina    AST      30    810.71
# 3  2020-01-02   Bellen    Zachód        Paulina   SFWK      19    418.54
# 22 2020-01-09  Carlota    Wschód     Franciszek    WSD      38    874.45
# 23 2020-01-09   Bellen    Wschód        Paulina    EPP      40    880.38
#
#     Koszty  commission_fee  Produkt_len  #_opakowań  Bonus Marka_samochodu
# 1   240.35         15.8550            6           5      0          Toyota
# 2   435.64         24.3213            4           6      0             BMW
# 3   190.05         12.5562            6           4      0             BMW
# 22  418.69         26.2335            7           8      0            Fiat
# 23  400.89         26.4114            6           8      0             BMW

# %%
df['Produkt'].str.upper().head()
# Out:
# 0        QUAD
# 1      BELLEN
# 2        QUAD
# 3      BELLEN
# 4    SUNSHINE
# Name: Produkt, dtype: object

# %%
df['Region'].str.endswith('ód').head()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Region, dtype: bool

# %%
df[df['Region'].str.contains('Zachód')].sample(5)
# Out:
#          Data  Produkt         Region Przedstawiciel Klient  Sztuki  Sprzedaż  \
# 76 2020-01-22   Bellen         Zachód        Paulina    AST      53   1166.31
# 28 2020-01-10  Carlota  ZachódCentrum        Paulina     AA      63   1449.21
# 73 2020-01-21     Quad         Zachód       Grzegorz    ITW      56   1512.60
# 99 2020-01-28  Carlota         Zachód         Patryk    LOP      15    345.88
# 29 2020-01-10     Quad  ZachódCentrum         Patryk    DFR      17    459.29
#
#     Koszty  commission_fee  Produkt_len  #_opakowań  Bonus Marka_samochodu
# 76  530.24         69.9786            6          11      0             BMW
# 28  693.64         86.9526            7          13      0             BMW
# 73  812.83         90.7560            4          12      0          Toyota
# 99  165.74         10.3764            7           3      0            Seat
# 29  246.75         13.7787            4           4      0            Seat

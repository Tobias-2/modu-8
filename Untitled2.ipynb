# %%
import pandas as pd
exam2 = [74,56,44,92]

e1 = pd.Series(exam1,labels)
e2 = pd.Series(exam2,labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       2 exam2 = [74,56,44,92]
# ----> 4 e1 = pd.Series(exam1,labels)
#       5 e2 = pd.Series(exam2,labels)
#
# NameError: name 'exam1' is not defined

# %%
df = pd.DataFrame({'e1':exam1, 'e2':exam2},index=labels)
df
# Out:
#            e1  e2
# Student A  89  74
# Student B  85  56
# Student C  93  44
# Student D  83  92

# %%
df['e3'] = [67,59,79,84]
df
# Out:
#            e1  e2  e3
# Student A  89  74  67
# Student B  85  56  59
# Student C  93  44  79
# Student D  83  92  84

# %%
df['semester1'] = df['e1'] + df['e2'] + df['e3']
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.reset_index()
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index = df.reset_index()
df_new_index
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index['student_name'] = ['Adrian','Bartłomiej','Celina','Dagmara']
df_new_index
# Out:
#        index  e1  e2  e3  semester1 student_name
# 0  Student A  89  74  67        230       Adrian
# 1  Student B  85  56  59        200   Bartłomiej
# 2  Student C  93  44  79        216       Celina
# 3  Student D  83  92  84        259      Dagmara

# %%
df_new_index.set_index('student_name')
# Out:
#                   index  e1  e2  e3  semester1
# student_name
# Adrian        Student A  89  74  67        230
# Bartłomiej    Student B  85  56  59        200
# Celina        Student C  93  44  79        216
# Dagmara       Student D  83  92  84        259

# %%
df_new_index2 = df.reset_index()
df_new_index2
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.rename(columns={'e1':'exam1','e2':'exam2','e3':'exam3'})
# Out:
#            exam1  exam2  exam3  semester1
# Student A     89     74     67        230
# Student B     85     56     59        200
# Student C     93     44     79        216
# Student D     83     92     84        259

# %%
df.rename(index={'Studnet C':'Student C'})
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.rename(str.upper, axis='columns')
# Out:
#            E1  E2  E3  SEMESTER1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df = pd.DataFrame({'A':[100,44,56,99,85,100],
                  'B':['Panda','Snake','Snake','Rat','Dog','Panda']})

# %%
df
# Out:
#      A      B
# 0  100  Panda
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog
# 5  100  Panda

# %%
exam1 = [89,85,93,83]
exam2 = [74,56,44,92]
exam3=[67,59,79,84]
df = pd.DataFrame({'e1':exam1, 'e2':exam2, 'e3':exam3}, index=labels)
df['semester1'] = df['e1']+df['e2']+df['e3']

# %%
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.set_index([pd.Index(['High School X','High School X','High School Y','High School Y']), df.index],inplace=True)

# %%
df
# Out:
#                          e1  e2  e3  semester1
# High School X Student A  89  74  67        230
#               Student B  85  56  59        200
# High School Y Student C  93  44  79        216
#               Student D  83  92  84        259

# %%
df.index.names = ['School','Student']
df
# Out:
#                          e1  e2  e3  semester1
# School        Student
# High School X Student A  89  74  67        230
#               Student B  85  56  59        200
# High School Y Student C  93  44  79        216
#               Student D  83  92  84        259

# %%
df.loc['High School X']
# Out:
#            e1  e2  e3  semester1
# Student
# Student A  89  74  67        230
# Student B  85  56  59        200

# %%
df.loc['High School X'].iloc[1]
# Out:
# e1            85
# e2            56
# e3            59
# semester1    200
# Name: Student B, dtype: int64

# %%
import numpy as np

# %%
x = np.random(1,101,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 x = np.random(1,101,4)
#
# TypeError: 'module' object is not callable

# %%
br = np.random(1,101,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 br = np.random(1,101,4)
#
# TypeError: 'module' object is not callable

# %%
dss = np.random.randit(1,101,4)
dss
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 dss = np.random.randit(1,101,4)
#       2 dss
#
# AttributeError: module 'numpy.random' has no attribute 'randit'

# %%
dss = np.random.randint(1,101,4)
dss
# Out:
# array([53, 90, 47, 60])

# %%
e4 = dss
e5 = dss
e6 = dss
e4
e5
e6
# Out:
# array([53, 90, 47, 60])

# %%
e4 = np.random.randint(1,101,4)

# %%
e4
# Out:
# array([92,  4, 38, 29])

# %%
e5 = np.random.randint(1,101,4)

# %%
e5
# Out:
# array([59, 46,  3, 20])

# %%
e6 = np.random.randint(1,101,4)

# %%
e6
# Out:
# array([88, 81, 75, 73])

# %%
df['e5'] = e5

# %%
df
# Out:
#                          e1  e2  e3  semester1  e5
# School        Student
# High School X Student A  89  74  67        230  59
#               Student B  85  56  59        200  46
# High School Y Student C  93  44  79        216   3
#               Student D  83  92  84        259  20

# %%
df['e4'] = e4

# %%
df
# Out:
#                          e1  e2  e3  semester1  e5  e4
# School        Student
# High School X Student A  89  74  67        230  59  92
#               Student B  85  56  59        200  46   4
# High School Y Student C  93  44  79        216   3  38
#               Student D  83  92  84        259  20  29

# %%
df['e6'] = e6

# %%
df
# Out:
#                          e1  e2  e3  semester1  e5  e4  e6
# School        Student
# High School X Student A  89  74  67        230  59  92  88
#               Student B  85  56  59        200  46   4  81
# High School Y Student C  93  44  79        216   3  38  75
#               Student D  83  92  84        259  20  29  73

# %%
df['semester2'] = df['e4'] + df['e5'] + df['e6']

# %%
df
# Out:
#                          e1  e2  e3  semester1  e5  e4  e6  semester2
# School        Student
# High School X Student A  89  74  67        230  59  92  88        239
#               Student B  85  56  59        200  46   4  81        131
# High School Y Student C  93  44  79        216   3  38  75        116
#               Student D  83  92  84        259  20  29  73        122

# %%
df.drop('semester1', axis=1, inplace = True)

# %%
df
# Out:
#                          e1  e2  e3  e5  e4  e6  semester2
# School        Student
# High School X Student A  89  74  67  59  92  88        239
#               Student B  85  56  59  46   4  81        131
# High School Y Student C  93  44  79   3  38  75        116
#               Student D  83  92  84  20  29  73        122

# %%
df
# Out:
#                          e1  e2  e3  e5  e4  e6  semester2
# School        Student
# High School X Student A  89  74  67  59  92  88        239
#               Student B  85  56  59  46   4  81        131
# High School Y Student C  93  44  79   3  38  75        116
#               Student D  83  92  84  20  29  73        122

# %%
f = pd.DataFrame({'Category':['Games','Games','Games',

                               'Film&Video','Film&Video','Film&Video'],

                  'Project_Title':['The Last Faith','Magic Puzzles','Dinosaur Fossil Hunter',

                                   'Beyond Your Eyes','5150','8-Bit Wars'],

                  'Pledged':[92774,2873519,7962,

                             276,23963,6950],

                  'Country':['UK','USA','Poland',

                             'Bulgaria','USA','UK'],

                  'Date_Start':['2020-03-21','2020-03-11','2020-04-16',

                                '2020-02-09','2020-04-10','2020-03-19']})

# %%
df = pd.DataFrame({'Category':['Games','Games','Games',

                               'Film&Video','Film&Video','Film&Video'],

                  'Project_Title':['The Last Faith','Magic Puzzles','Dinosaur Fossil Hunter',

                                   'Beyond Your Eyes','5150','8-Bit Wars'],

                  'Pledged':[92774,2873519,7962,

                             276,23963,6950],

                  'Country':['UK','USA','Poland',

                             'Bulgaria','USA','UK'],

                  'Date_Start':['2020-03-21','2020-03-11','2020-04-16',

                                '2020-02-09','2020-04-10','2020-03-19']})

# %%
df
# Out:
#      Category           Project_Title  Pledged   Country  Date_Start
# 0       Games          The Last Faith    92774        UK  2020-03-21
# 1       Games           Magic Puzzles  2873519       USA  2020-03-11
# 2       Games  Dinosaur Fossil Hunter     7962    Poland  2020-04-16
# 3  Film&Video        Beyond Your Eyes      276  Bulgaria  2020-02-09
# 4  Film&Video                    5150    23963       USA  2020-04-10
# 5  Film&Video              8-Bit Wars     6950        UK  2020-03-19

# %%
df.groupby('Category')

# %%
df.groupby('Category')

# %%
df.groupby(pd.Grouper(key='Date_Start',freq='M')).agg({'Pledged':'sum','Project_Title':'count'})
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_45280\4056686556.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.groupby(pd.Grouper(key='Date_Start',freq='M')).agg({'Pledged':'sum','Project_Title':'count'})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 df.groupby(pd.Grouper(key='Date_Start',freq='M')).agg({'Pledged':'sum','Project_Title':'count'})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:929, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     927 # a passed-in Grouper, directly convert
#     928 if isinstance(key, Grouper):
# --> 929     grouper, obj = key._get_grouper(obj, validate=False)
#     930     if key.key is None:
#     931         return grouper, frozenset(), obj
#
# File ~\anaconda3\Lib\site-packages\pandas\core\resample.py:2282, in TimeGrouper._get_grouper(self, obj, validate)
#    2278 def _get_grouper(
#    2279     self, obj: NDFrameT, validate: bool = True
#    2280 ) -> tuple[BinGrouper, NDFrameT]:
#    2281     # create the resampler and return our binner
# -> 2282     r = self._get_resampler(obj)
#    2283     return r._grouper, cast(NDFrameT, r.obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\resample.py:2272, in TimeGrouper._get_resampler(self, obj, kind)
#    2263 elif isinstance(ax, TimedeltaIndex):
#    2264     return TimedeltaIndexResampler(
#    2265         obj,
#    2266         timegrouper=self,
#    (...)
#    2269         gpr_index=ax,
#    2270     )
# -> 2272 raise TypeError(
#    2273     "Only valid with DatetimeIndex, "
#    2274     "TimedeltaIndex or PeriodIndex, "
#    2275     f"but got an instance of '{type(ax).__name__}'"
#    2276 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %%
df['Date_Start'] = pd.to_datetime(df['Date_Start'])

# %%
df.groupby(pd.Grouper(key='Date_Start',freq='M')).sum()
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_45280\64595916.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.groupby(pd.Grouper(key='Date_Start',freq='M')).sum()
#                         Category                          Project_Title  \
# Date_Start
# 2020-02-29            Film&Video                       Beyond Your Eyes
# 2020-03-31  GamesFilm&VideoGames  Magic Puzzles8-Bit WarsThe Last Faith
# 2020-04-30       Film&VideoGames             5150Dinosaur Fossil Hunter
#
#             Pledged    Country
# Date_Start
# 2020-02-29      276   Bulgaria
# 2020-03-31  2973243    USAUKUK
# 2020-04-30    31925  USAPoland

# %%
pd.Grouper(key=’Date_Start’,freq=’M’)
# Out:
#   Cell In[118], line 1
#     pd.Grouper(key=’Date_Start’,freq=’M’)
#                    ^
# SyntaxError: invalid character '’' (U+2019)

# %%
df.groupby(pd.Grouper(key='Date_Start',freq='M')).agg({'Pledged':'sum','Project_Title':'count'})
# Out:
# C:\Users\Start\AppData\Local\Temp\ipykernel_45280\4056686556.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.groupby(pd.Grouper(key='Date_Start',freq='M')).agg({'Pledged':'sum','Project_Title':'count'})
#             Pledged  Project_Title
# Date_Start
# 2020-02-29      276              1
# 2020-03-31  2973243              3
# 2020-04-30    31925              2

# %%
df_with_nulls = pd.DataFrame({'A':[1,100,np.nan,1000,10000],
                             'B':[2,4,2,4,np.nan],
                             'C':[40,np.nan,20,np.nan,np.nan]})
df_with_nulls
# Out:
#          A    B     C
# 0      1.0  2.0  40.0
# 1    100.0  4.0   NaN
# 2      NaN  2.0  20.0
# 3   1000.0  4.0   NaN
# 4  10000.0  NaN   NaN

# %%
import pandas as pd

# %%
import numpy as np

# %%
import missingno as msno

# %%
msno.matrix(df_with_nulls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 msno.matrix(df_with_nulls)
#
# NameError: name 'df_with_nulls' is not defined

# %%
df = pd.DataFrame({'Category':['Games','Games','Games',

                               'Film&Video','Film&Video','Film&Video'],

                  'Project_Title':['The Last Faith','Magic Puzzles','Dinosaur Fossil Hunter',

                                   'Beyond Your Eyes','5150','8-Bit Wars'],

                  'Pledged':[92774,2873519,7962,

                             276,23963,6950],

                  'Country':['UK','USA','Poland',

                             'Bulgaria','USA','UK'],

                  'Date_Start':['2020-03-21','2020-03-11','2020-04-16',

                                '2020-02-09','2020-04-10','2020-03-19']})

# %%
df_with_nulls = pd.DataFrame({'A':[1,100,np.nan,1000,10000],
                             'B':[2,4,2,4,np.nan],
                             'C':[40,np.nan,20,np.nan,np.nan]})
df_with_nulls
# Out:
#          A    B     C
# 0      1.0  2.0  40.0
# 1    100.0  4.0   NaN
# 2      NaN  2.0  20.0
# 3   1000.0  4.0   NaN
# 4  10000.0  NaN   NaN

# %%
msno.matrix(df_with_nulls)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 msno.matrix(df_with_nulls)
#
# File ~\anaconda3\Lib\site-packages\missingno\missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3196, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3194 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3195 if axis in ['x', 'both']:
# -> 3196     self.xaxis.grid(visible, which=which, **kwargs)
#    3197 if axis in ['y', 'both']:
#    3198     self.yaxis.grid(visible, which=which, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1697, in Axis.grid(self, visible, which, **kwargs)
#    1694 if which in ['major', 'both']:
#    1695     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1696                         if visible is None else visible)
# -> 1697     self.set_tick_params(which='major', **gridkw)
#    1698 self.stale = True
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:958, in Axis.set_tick_params(self, which, reset, **kwargs)
#     945 """
#     946 Set appearance parameters for ticks, ticklabels, and gridlines.
#     947
#    (...)
#     955     gridlines.
#     956 """
#     957 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 958 kwtrans = self._translate_tick_params(kwargs)
#     960 # the kwargs are stored in self._major/minor_tick_kw so that any
#     961 # future new ticks will automatically get them
#     962 if reset:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1102, in Axis._translate_tick_params(kw, reverse)
#    1100 for key in kw_:
#    1101     if key not in allowed_keys:
# -> 1102         raise ValueError(
#    1103             "keyword %s is not recognized; valid keywords are %s"
#    1104             % (key, allowed_keys))
#    1105 kwtrans.update(kw_)
#    1106 return kwtrans
#
# ValueError: keyword grid_b is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'labelfontfamily', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']

# %%
df_with_nulls.dropna()
# Out:
#      A    B     C
# 0  1.0  2.0  40.0

# %%
df_with_nulls.fillna('NOWA WARTOŚĆ')
# Out:
#               A             B             C
# 0           1.0           2.0          40.0
# 1         100.0           4.0  NOWA WARTOŚĆ
# 2  NOWA WARTOŚĆ           2.0          20.0
# 3        1000.0           4.0  NOWA WARTOŚĆ
# 4       10000.0  NOWA WARTOŚĆ  NOWA WARTOŚĆ

# %%
df_with_nulls['B'].fillna(df_with_nulls['B'].mean())
# Out:
# 0    2.0
# 1    4.0
# 2    2.0
# 3    4.0
# 4    3.0
# Name: B, dtype: float64

# %%
df_with_nulls['B'].fillna(df_with_nulls['B'].ffill())
# Out:
# 0    2.0
# 1    4.0
# 2    2.0
# 3    4.0
# 4    4.0
# Name: B, dtype: float64

# %%
df_with_nulls['A'].fillna(df_with_nulls['A'].ffill())
# Out:
# 0        1.0
# 1      100.0
# 2      100.0
# 3     1000.0
# 4    10000.0
# Name: A, dtype: float64

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],

                    'B': ['B0', 'B1', 'B2', 'B3'],

                    'C': ['C0', 'C1', 'C2', 'C3'],

                    'D': ['D0', 'D1', 'D2', 'D3']},

                    index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],

                    'B': ['B4', 'B5', 'B6', 'B7'],

                    'C': ['C4', 'C5', 'C6', 'C7'],

                    'D': ['D4', 'D5', 'D6', 'D7']},

                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],

                    'B': ['B8', 'B9', 'B10', 'B11'],

                    'C': ['C8', 'C9', 'C10', 'C11'],

                    'D': ['D8', 'D9', 'D10', 'D11']},

                    index=[8, 9, 10, 11])

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
s = pd.Series(['S1','S2','S3','S4'])
pd.concat([df1,s])
# Out:
#      A    B    C    D    0
# 0   A0   B0   C0   D0  NaN
# 1   A1   B1   C1   D1  NaN
# 2   A2   B2   C2   D2  NaN
# 3   A3   B3   C3   D3  NaN
# 0  NaN  NaN  NaN  NaN   S1
# 1  NaN  NaN  NaN  NaN   S2
# 2  NaN  NaN  NaN  NaN   S3
# 3  NaN  NaN  NaN  NaN   S4

# %%
pd.concat([df1,df2,df3],axis=1,keys=['first','second','third'])
# Out:
#    first                second                third
#        A    B    C    D      A    B    C    D     A    B    C    D
# 0     A0   B0   C0   D0    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 1     A1   B1   C1   D1    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 2     A2   B2   C2   D2    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 3     A3   B3   C3   D3    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN     A4   B4   C4   D4   NaN  NaN  NaN  NaN
# 5    NaN  NaN  NaN  NaN     A5   B5   C5   D5   NaN  NaN  NaN  NaN
# 6    NaN  NaN  NaN  NaN     A6   B6   C6   D6   NaN  NaN  NaN  NaN
# 7    NaN  NaN  NaN  NaN     A7   B7   C7   D7   NaN  NaN  NaN  NaN
# 8    NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN    A8   B8   C8   D8
# 9    NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN    A9   B9   C9   D9
# 10   NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN   A10  B10  C10  D10
# 11   NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN   A11  B11  C11  D11

# %%
result = pd.concat([df1, df2, df3], axis=1)

# %%
result
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
def make_keys(n):
    return [f'key{n}' for n in range(n)]
left = df1.copy()
left['key'] = make_keys(4)
right = df3.copy()
right['key'] = make_keys(4)

# %%
left
# Out:
#     A   B   C   D   key
# 0  A0  B0  C0  D0  key0
# 1  A1  B1  C1  D1  key1
# 2  A2  B2  C2  D2  key2
# 3  A3  B3  C3  D3  key3

# %%
right
# Out:
#       A    B    C    D   key
# 8    A8   B8   C8   D8  key0
# 9    A9   B9   C9   D9  key1
# 10  A10  B10  C10  D10  key2
# 11  A11  B11  C11  D11  key3

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   A_x B_x C_x D_x   key  A_y  B_y  C_y  D_y
# 0  A0  B0  C0  D0  key0   A8   B8   C8   D8
# 1  A1  B1  C1  D1  key1   A9   B9   C9   D9
# 2  A2  B2  C2  D2  key2  A10  B10  C10  D10
# 3  A3  B3  C3  D3  key3  A11  B11  C11  D11

# %%
pd.merge(left,new_right,how='outer',on='key')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pd.merge(left,new_right,how='outer',on='key')
#
# NameError: name 'new_right' is not defined

# %%
new_right = pd.DataFrame({'E': ['E1','E2','E3','E4','E5','E6'],
                          'key': make_keys(6)})
new_right
# Out:
#     E   key
# 0  E1  key0
# 1  E2  key1
# 2  E3  key2
# 3  E4  key3
# 4  E5  key4
# 5  E6  key5

# %%
pd.merge(left,new_right,how='inner',on='key')
# Out:
#     A   B   C   D   key   E
# 0  A0  B0  C0  D0  key0  E1
# 1  A1  B1  C1  D1  key1  E2
# 2  A2  B2  C2  D2  key2  E3
# 3  A3  B3  C3  D3  key3  E4

# %%
pd.merge(left,new_right,how='outer',on='key')
# Out:
#      A    B    C    D   key   E
# 0   A0   B0   C0   D0  key0  E1
# 1   A1   B1   C1   D1  key1  E2
# 2   A2   B2   C2   D2  key2  E3
# 3   A3   B3   C3   D3  key3  E4
# 4  NaN  NaN  NaN  NaN  key4  E5
# 5  NaN  NaN  NaN  NaN  key5  E6

# %%
other = pd.DataFrame({'E':['E1','E2','E3','E4','E5','E6']},index=['B1','B2','B3','B4','B5','B6'])

# %%
other
# Out:
#      E
# B1  E1
# B2  E2
# B3  E3
# B4  E4
# B5  E5
# B6  E6

# %%
def make_keys(n):
    return [f'key{n}' for n in range(n)]
left = df1.copy()
left['key'] = make_keys(4)
right = df3.copy()
right['key'] = make_keys(4)

# %%
left.join(right,on='key', how 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 left.join(right,on='key')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
#   10769     if on is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:807, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     803 self._validate_tolerance(self.left_join_keys)
#     805 # validate the merge keys dtypes. We may need to coerce
#     806 # to avoid incompatible dtypes
# --> 807 self._maybe_coerce_merge_keys()
#     809 # If argument passed to validate,
#     810 # check if columns specified as unique
#     811 # are in fact unique.
#     812 if validate is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1508, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1502     # unless we are merging non-string-like with string-like
#    1503     elif (
#    1504         inferred_left in string_types and inferred_right not in string_types
#    1505     ) or (
#    1506         inferred_right in string_types and inferred_left not in string_types
#    1507     ):
# -> 1508         raise ValueError(msg)
#    1510 # datetimelikes must match exactly
#    1511 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns for key 'key'. If you wish to proceed you should use pd.concat

# %%
left.join(right, lsuffix='_left', rsuffix='_right', how='left')
# Out:
#   A_left B_left C_left D_left key_left A_right B_right C_right D_right  \
# 0     A0     B0     C0     D0     key0     NaN     NaN     NaN     NaN
# 1     A1     B1     C1     D1     key1     NaN     NaN     NaN     NaN
# 2     A2     B2     C2     D2     key2     NaN     NaN     NaN     NaN
# 3     A3     B3     C3     D3     key3     NaN     NaN     NaN     NaN
#
#   key_right
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN

# %%
left.join(right,on= 'key')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 left.join(right,on= 'key')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
#   10769     if on is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:807, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     803 self._validate_tolerance(self.left_join_keys)
#     805 # validate the merge keys dtypes. We may need to coerce
#     806 # to avoid incompatible dtypes
# --> 807 self._maybe_coerce_merge_keys()
#     809 # If argument passed to validate,
#     810 # check if columns specified as unique
#     811 # are in fact unique.
#     812 if validate is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1508, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1502     # unless we are merging non-string-like with string-like
#    1503     elif (
#    1504         inferred_left in string_types and inferred_right not in string_types
#    1505     ) or (
#    1506         inferred_right in string_types and inferred_left not in string_types
#    1507     ):
# -> 1508         raise ValueError(msg)
#    1510 # datetimelikes must match exactly
#    1511 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns for key 'key'. If you wish to proceed you should use pd.concat

# %%
df = pd.read_csv('myCsvFile.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 df = pd.read_csv('myCsvFile.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myCsvFile.csv'

# %%
df.to_csv('myNewCsvFile.csv', index=False)

# %%
df = pd.read_csv('myCsvFile.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df = pd.read_csv('myCsvFile.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myCsvFile.csv'

# %%
df.to_csv('myNewCsvFile.csv', index=False)

# %%
import pandas as pd
df = pd.read_excel('myExcelFile.xlsx', sheet_name='my_data')

# %%
df.to_excel('myNewExcelFile.xlsx', sheet_name='my_new_data')

# %%
writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:197, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     184 def __init__(
#     185     self,
#     186     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#     195 ) -> None:
#     196     # Use the xlsxwriter module as the Excel writer.
# --> 197     from xlsxwriter import Workbook
#     199     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#     201     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %%
import pandas as pd
df = pd.read_excel('myExcelFile.xlsx', sheet_name='my_data')

# %%
df.to_excel('myNewExcelFile.xlsx', sheet_name='my_new_data')

# %%
writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')

# %%
df.to_excel(writer, sheet_name='my_dfs')
df.to_excel(writer, sheet_name='my_dfs', startcol=6, startrow=5, index=False)

# %%
df.to_excel(writer, sheet_name='my_dfs')
df.to_excel(writer, sheet_name='my_dfs', startcol=6, startrow=5, index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 writer.save()
#
# AttributeError: 'XlsxWriter' object has no attribute 'save'

# %%
df.to_excel(writer, sheet_name='my_dfs')
df.to_excel(writer, sheet_name='my_dfs', startcol=6, startrow=5, index=False)

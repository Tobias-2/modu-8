# %%
import pandas as pd

# %%
df = pd.read_csv('fatal-police-shootings-data.csv')

# %%
df
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
import numpy as np

# %%
df.pivot_table(values='id',index=['signs_of_mental_illness','race'],aggfunc=[len]).round(0)
# Out:
#                                len
#                                 id
# signs_of_mental_illness race
# False                   A       69
#                         B     1114
#                         H      745
#                         N       64
#                         O       37
#                         W     1763
# True                    A       24
#                         B      184
#                         H      157
#                         N       14
#                         O       11
#                         W      713

# %%
df2 = df.pivot_table(values='id',index=['signs_of_mental_illness','race'],aggfunc=[len]).round(0)

# %%
df2
# Out:
#                                len
#                                 id
# signs_of_mental_illness race
# False                   A       69
#                         B     1114
#                         H      745
#                         N       64
#                         O       37
#                         W     1763
# True                    A       24
#                         B      184
#                         H      157
#                         N       14
#                         O       11
#                         W      713

# %%
df2.rename(columns={'id':'deaths'})
# Out:
#                                 len
#                              deaths
# signs_of_mental_illness race
# False                   A        69
#                         B      1114
#                         H       745
#                         N        64
#                         O        37
#                         W      1763
# True                    A        24
#                         B       184
#                         H       157
#                         N        14
#                         O        11
#                         W       713

# %%
df3 = df.groupby(['race', 'signs_of_mental_illness']).size().unstack(fill_value=0)

# %%
df3
# Out:
# signs_of_mental_illness  False  True
# race
# A                           69     24
# B                         1114    184
# H                          745    157
# N                           64     14
# O                           37     11
# W                         1763    713

# %%
df3.columns = ['no_mental_illness', 'mental_illness']

# %%
df3
# Out:
#       no_mental_illness  mental_illness
# race
# A                    69              24
# B                  1114             184
# H                   745             157
# N                    64              14
# O                    37              11
# W                  1763             713

# %%
df3['total'] = df3['no_mental_illness'] + df3['mental_illness']

# %%
df3
# Out:
#       no_mental_illness  mental_illness  total
# race
# A                    69              24     93
# B                  1114             184   1298
# H                   745             157    902
# N                    64              14     78
# O                    37              11     48
# W                  1763             713   2476

# %%
df3['mental_percentage'] = (df3['mental_illness'] / df3['total']) * 100

# %%
df3
# Out:
#       no_mental_illness  mental_illness  total  mental_percentage
# race
# A                    69              24     93          25.806452
# B                  1114             184   1298          14.175655
# H                   745             157    902          17.405765
# N                    64              14     78          17.948718
# O                    37              11     48          22.916667
# W                  1763             713   2476          28.796446

# %%
df
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df = df.dropna(subset=['date'])

# %%
df['weekday'] = df['date'].dt.day_name()

# %%
weekday_counts = df['weekday'].value_counts()

# %%
weekday_counts = weekday_counts.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# %%
weekday_counts
# Out:
# weekday
# Monday       726
# Tuesday      816
# Wednesday    829
# Thursday     810
# Friday       761
# Saturday     721
# Sunday       753
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
weekday_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of Deaths by Weekday')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Deaths')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
polulation_USA = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states_by_population', header=0)

# %%
polulation_USA_in_particular_states = polulation_USA[0]

# %%
polulation_USA_in_particular_states
# Out:
#    Rank in states & territories, 2020 Rank in states & territories, 2010  \
# 0                                   1                                  1
# 1                                   2                                  2
# 2                                   3                                  4
# 3                                   4                                  3
# 4                                   5                                  6
# 5                                   6                                  5
# 6                                   7                                  7
# 7                                   8                                  9
# 8                                   9                                 10
# 9                                  10                                  8
# 10                                 11                                 11
# 11                                 12                                 12
# ...

# %%
shortcuts_USA = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._state_and_territory_abbreviations', header=0)

# %%
shortcuts_USA_of_particular_states = shortcuts_USA[1]

# %%
shortcuts_USA_of_particular_states
# Out:
#                                       Name         Status of region  \
# 0                                     Name         Status of region
# 1                 United States of America            Federal state
# 2                                  Alabama                    State
# 3                                   Alaska                    State
# 4                                  Arizona                    State
# ..                                     ...                      ...
# 74                                Nebraska  Obsolete postal code[g]
# 75                Northern Mariana Islands  Obsolete postal code[h]
# 76                       Panama Canal Zone     Obsolete postal code
# 77                      Philippine Islands     Obsolete postal code
# 78  Trust Territory of the Pacific Islands     Obsolete postal code
#
#                ISO ANSI  ANSI.1 USPS USCG     GPO      AP  Other abbreviations
# ...

# %%
death_in_specific_states = df.pivot_table(values='id',index=['state'],aggfunc=[len]).round(0)

# %%
death_in_specific_states
# Out:
#        len
#         id
# state
# AK      39
# AL     104
# AR      83
# AZ     254
# CA     799
# CO     195
# CT      21
# DC      13
# DE      13
# FL     350
# GA     182
# HI      30
# IA      32
# ID      42
# IL     104
# IN      95
# KS      50
# KY      95
# LA     109
# MA      35
# MD      79
# ME      22
# MI      78
# MN      61
# MO     141
# MS      65
# MT      31
# NC     156
# ND      11
# NE      24
# NH      13
# NJ      68
# NM     106
# NV      96
# NY     101
# OH     155
# OK     164
# OR      88
# PA     108
# RI       4
# SC      88
# SD      17
# TN     139
# TX     481
# UT      60
# VA      95
# VT       9
# WA     152
# WI      91
# WV      54
# WY      14

# %%
death_in_specific_states.rename(columns={'id':'deaths'})
# Out:
#          len
#       deaths
# state
# AK        39
# AL       104
# AR        83
# AZ       254
# CA       799
# CO       195
# CT        21
# DC        13
# DE        13
# FL       350
# GA       182
# HI        30
# IA        32
# ID        42
# IL       104
# IN        95
# KS        50
# KY        95
# LA       109
# MA        35
# MD        79
# ME        22
# MI        78
# MN        61
# MO       141
# MS        65
# MT        31
# NC       156
# ND        11
# NE        24
# NH        13
# NJ        68
# NM       106
# NV        96
# NY       101
# OH       155
# OK       164
# OR        88
# PA       108
# RI         4
# SC        88
# SD        17
# TN       139
# TX       481
# UT        60
# VA        95
# VT         9
# WA       152
# WI        91
# WV        54
# WY        14

# %%
full_names = shortcuts_USA_of_particular_states.pivot_table(values='Name',index=['ANSI'],aggfunc=[str])

# %%
full_names = shortcuts_USA_of_particular_states.pivot_table(
    values='Name',
    index=['ANSI'],
    aggfunc=lambda x: ', '.join(x)
)

# %%
full_names
# Out:
#                 Name
# ANSI
# AK            Alaska
# AL           Alabama
# AR          Arkansas
# AS    American Samoa
# AZ           Arizona
# ...              ...
# VT           Vermont
# WA        Washington
# WI         Wisconsin
# WV     West Virginia
# WY           Wyoming
#
# [61 rows x 1 columns]

# %%
population = polulation_USA_in_particular_states.pivot_table(
    values='Census population, April 1, 2020 [1][2]',  
    index=['State'],  
    aggfunc='sum'  
)

# %%
population
# Out:
#                                              Census population, April 1, 2020 [1][2]
# State
# Alabama                                                                      5024279
# Alaska                                                                        733391
# American Samoa                                                                 49710
# Arizona                                                                      7151502
# Arkansas                                                                     3011524
# California                                                                  39538223
# Colorado                                                                     5773714
# Connecticut                                                                  3605944
# Contiguous United States                                                   329260619
# Delaware                                                                      989948
# ...

# %%
full_names.rename(index={'ANSI':'state'})
# Out:
#                 Name
# ANSI
# AK            Alaska
# AL           Alabama
# AR          Arkansas
# AS    American Samoa
# AZ           Arizona
# ...              ...
# VT           Vermont
# WA        Washington
# WI         Wisconsin
# WV     West Virginia
# WY           Wyoming
#
# [61 rows x 1 columns]

# %%
pd.concat([death_in_specific_states,full_names],axis=1)
# Out:
#     (len, id)                         Name
# AK       39.0                       Alaska
# AL      104.0                      Alabama
# AR       83.0                     Arkansas
# AZ      254.0                      Arizona
# CA      799.0                   California
# ..        ...                          ...
# PR        NaN                  Puerto Rico
# PW        NaN                        Palau
# UM        NaN  U.S. Minor Outlying Islands
# US        NaN     United States of America
# VI        NaN          U.S. Virgin Islands
#
# [61 rows x 2 columns]

# %%
full_names_and_deaths = pd.concat([death_in_specific_states,full_names],axis=1)

# %%
full_names_and_deaths
# Out:
#     (len, id)                         Name
# AK       39.0                       Alaska
# AL      104.0                      Alabama
# AR       83.0                     Arkansas
# AZ      254.0                      Arizona
# CA      799.0                   California
# ..        ...                          ...
# PR        NaN                  Puerto Rico
# PW        NaN                        Palau
# UM        NaN  U.S. Minor Outlying Islands
# US        NaN     United States of America
# VI        NaN          U.S. Virgin Islands
#
# [61 rows x 2 columns]

# %%
a3 = full_names_and_deaths.reset_index()  
pivot_switched = full_names_and_deaths.set_index('Name')

# %%
pivot_switched
# Out:
#                              (len, id)
# Name
# Alaska                            39.0
# Alabama                          104.0
# Arkansas                          83.0
# Arizona                          254.0
# California                       799.0
# ...                                ...
# Puerto Rico                        NaN
# Palau                              NaN
# U.S. Minor Outlying Islands        NaN
# United States of America           NaN
# U.S. Virgin Islands                NaN
#
# [61 rows x 1 columns]

# %%
all_three = pd.concat([pivot_switched,population],axis=1)

# %%
all_three
# Out:
#                                              (len, id)  \
# Alaska                                            39.0
# Alabama                                          104.0
# Arkansas                                          83.0
# Arizona                                          254.0
# California                                       799.0
# ...                                                ...
# U.S. Virgin Islands                                NaN
# Contiguous United States                           NaN
# Fifty states + D.C.                                NaN
# The fifty states                                   NaN
# Total U.S. (including D.C. and territories)        NaN
#
#                                              Census population, April 1, 2020 [1][2]
# Alaska                                                                      733391.0
# Alabama                                                                    5024279.0
# ...

# %%
all_three['incidents_for_1000_inhabitant'] = (all_three['(len, id)'] / all_three['Census population, April 1, 2020 [1][2]']) * 1000
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '(len, id)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[252], line 1
# ...
